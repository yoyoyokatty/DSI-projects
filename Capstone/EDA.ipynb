# %% [markdown]
# iTunes doesn't allow you to pull unless you have a search parameter - have to import artists from another source
#
# Based off of genres in iTunes:
#
# - Alternative
# - Blues
# - Country
# - Dance
# - Electronic
# - Hip Hop/Rap
# - Indie
# - Jazz
# - Metal
# - Pop
# - R&B Soul
# - Reggae
# - Rock
# - Singer/Songwriters
#
# https://en.wikipedia.org/wiki/Lists_of_musicians
#
# https://en.wikipedia.org/wiki/List_of_reggae_musicians
# https://en.wikipedia.org/wiki/List_of_country_rock_musicians
# https://en.wikipedia.org/wiki/List_of_alternative_rock_artists
# https://en.wikipedia.org/wiki/List_of_blues_musicians
# https://en.wikipedia.org/wiki/List_of_country_music_performers
# https://en.wikipedia.org/wiki/List_of_dance-pop_artists
# https://en.wikipedia.org/wiki/List_of_house_music_artists
# https://en.wikipedia.org/wiki/List_of_electro_house_artists
# https://en.wikipedia.org/wiki/List_of_ambient_music_artists
# https://en.wikipedia.org/wiki/Category:Breakbeat_musicians
# https://en.wikipedia.org/wiki/List_of_disco_artists_(A%E2%80%93E)
# https://en.wikipedia.org/wiki/List_of_disco_artists_(F%E2%80%93K)
# https://en.wikipedia.org/wiki/List_of_disco_artists_(L%E2%80%93R)
# https://en.wikipedia.org/wiki/List_of_disco_artists_(S%E2%80%93Z)
# https://en.wikipedia.org/wiki/List_of_downtempo_artists
# https://en.wikipedia.org/wiki/List_of_jungle_and_drum_and_bass_artists
# https://en.wikipedia.org/wiki/List_of_dub_artists
# https://en.wikipedia.org/wiki/Future_bass
# https://en.wikipedia.org/wiki/Category:Electronic_rock_musical_groups
# https://en.wikipedia.org/wiki/List_of_hardcore_punk_bands
# https://en.wikipedia.org/wiki/List_of_post-hardcore_bands
# https://en.wikipedia.org/wiki/List_of_Hi-NRG_artists_and_songs
# https://en.wikipedia.org/wiki/List_of_house_music_artists
# https://en.wikipedia.org/wiki/List_of_industrial_music_bands
# https://en.wikipedia.org/wiki/List_of_intelligent_dance_music_artists
# https://en.wikipedia.org/wiki/List_of_vocal_trance_artists
# https://en.wikipedia.org/wiki/List_of_UK_garage_artists
# https://en.wikipedia.org/wiki/List_of_hip_hop_groups
# https://en.wikipedia.org/wiki/List_of_hip_hop_musicians
# https://en.wikipedia.org/wiki/List_of_rap_rock_bands
# https://en.wikipedia.org/wiki/List_of_gangsta_rap_artists
# https://en.wikipedia.org/wiki/List_of_indie_rock_musicians
# https://en.wikipedia.org/wiki/List_of_indie_pop_artists
# https://en.wikipedia.org/wiki/List_of_jazz_musicians
# https://en.wikipedia.org/wiki/List_of_soul_jazz_musicians
# https://en.wikipedia.org/wiki/List_of_smooth_jazz_musicians
# https://en.wikipedia.org/wiki/List_of_alternative_metal_artists
# https://en.wikipedia.org/wiki/List_of_heavy_metal_bands
# https://en.wikipedia.org/w/index.php?title=Category:American_female_pop_singers&pageuntil=Longet%2C+Claudine%0AClaudine+Longet#mw-pages
# https://en.wikipedia.org/w/index.php?title=Category:American_female_pop_singers&pagefrom=Longet%2C+Claudine%0AClaudine+Longet#mw-pages
ipedia.org/wiki/List_of_1970s_punk_rock_musicians", "https://en.wikipedia.org/wiki/List_of_musicians_in_the_second_wave_of_punk_rock", "https://en.wikipedia.org/wiki/List_of_progressive_house_artists", "https://en.wikipedia.org/wiki/List_of_blues_rock_musicians", "https://en.wikipedia.org/wiki/List_of_dance-rock_artists", "https://en.wikipedia.org/wiki/List_of_folk_rock_artists", "https://en.wikipedia.org/wiki/List_of_funk_rock_bands", "https://en.wikipedia.org/wiki/List_of_garage_rock_bands", "https://en.wikipedia.org/wiki/List_of_glam_rock_artists", "https://en.wikipedia.org/wiki/List_of_soft_rock_artists_and_songs", "https://en.wikipedia.org/wiki/List_of_singer-songwriters"]

# %%
len(list_artists)
# Out:
# 69

# %%
list_wiki = []

for url in list_artists:
    url = url.replace("https://en.wikipedia.org/wiki/", "").replace("_", " ").replace("https://en.wikipedia.org/w/index.php?title=", "")
    list_wiki.append(url)

# %%
for url in list_wiki:
    print url
# Out:
# List of reggae musicians
# List of country rock musicians
# List of alternative rock artists
# List of blues musicians
# List of country music performers
# List of dance-pop artists
# List of house music artists
# List of electro house artists
# List of ambient music artists
# Category:Breakbeat musicians
# List of disco artists (A%E2%80%93E)
# List of disco artists (F%E2%80%93K)
# List of disco artists (L%E2%80%93R)
# List of disco artists (S%E2%80%93Z)
# List of downtempo artists
# List of jungle and drum and bass artists
# List of dub artists
# Future bass
# Category:Electronic rock musical groups
# List of hardcore punk bands,List of post-hardcore bands
# List of Hi-NRG artists and songs
# List of house music artists
# List of industrial music bands
# List of intelligent dance music artists
# List of vocal trance artists
# List of UK garage artists
# List of hip hop groups
# List of hip hop musicians
# List of rap rock bands
# List of gangsta rap artists
# ...

# %%
content_list = []

for i in list_wiki:
    try:
        genre_artist = wikipedia.page(i)
        article = genre_artist.links
        content_list.append(article)
    except:
        print i 
        pass
# Out:
# List of disco artists (A%E2%80%93E)
# List of disco artists (F%E2%80%93K)
# List of disco artists (L%E2%80%93R)
# List of disco artists (S%E2%80%93Z)
# Category:Electronic rock musical groups
# Category:American female pop singers&pageuntil=Longet%2C+Claudine%0AClaudine+Longet#mw-pages
# Category:American female pop singers&pagefrom=Longet%2C+Claudine%0AClaudine+Longet#mw-pages
# Category:American male pop singers
# Category:American boy bands
# Category:American pop rock singers
# Category:American pop singer stubs
# List of R%26B musicians
# List of hard rock musicians (A%E2%80%93M)
# List of hard rock musicians (N%E2%80%93Z)
# List of punk rock bands, 0%E2%80%93K
# List of punk rock bands, L%E2%80%93Z

# %%
content_list
# Out:
# [[u'Admiral Bailey',
#   u'Admiral T',
#   u'African Brothers',
#   u'Aisha (reggae singer)',
#   u'Al Anderson (The Wailers)',
#   u'Al Campbell',
#   u'Alaine',
#   u'Alborosie',
#   u'Alozade',
#   u'Alpha & Omega (band)',
#   u'Alpha Blondy',
#   u'Althea & Donna',
#   u'Alton Ellis',
#   u'Andrew Tosh',
#   u'Andru Branch',
#   u'Annette Brissett',
#   u'Ansell Collins',
#   u'Anthony B',
#   u'Anthony Johnson (musician)',
#   u'Apache Indian (rapper)',
#   u'Aston Barrett',
#   u'Aswad (band)',
#   u'Audio Active',
#   u'Audrey Hall',
#   u'Augustus "Gussie" Clarke',
#   u'Augustus Pablo',
#   u'Aura Lewis',
#   u'B.B. Seaton',
#   u'Baba Brooks',
#   u'Baby Cham',
#   u'Baby Wayne',
#   u'Bad Brains',
#   u'Barrington Levy',
#   u'Barry Biggs',
#   u'Barry Boom',
#   u'Barry Brown (singer)',
#   u'Bedouin Soundclash',
#   u'Beenie Man',
#   u'Benjamin Zephaniah',
#   u'Beres Hammond',
#   u'Beshara (band)',
#   u'Big Joe (reggae)',
#   u'Big Mountain (band)',
# ...

# %%
leftover_urls = ["list of disco artists", "Electronic rock musical groups", "American female pop singers", "American male pop singers", "American boy bands", "American pop rock singers", "American pop rock singers", "American pop singer stubs", 'List of R&B musicians', "List of hard rock musicians", "List of punk rock bands"]

leftover_titles = []

for i in leftover_urls:
    search_results = wikipedia.search(i)
    leftover_titles.append(search_results)

# %%
leftover_titles
# Out:
# [[u'List of disco artists',
#   u'List of disco artists (L\u2013R)',
#   u'List of Euro disco artists',
#   u'List of disco artists (F\u2013K)',
#   u'List of disco artists (S\u2013Z)',
#   u'List of disco artists (A\u2013E)',
#   u'List of Italo disco artists and songs',
#   u'List of post-disco artists and songs',
#   u'YBS',
#   u'Lists of musicians'],
#  [u'Filthy Dukes',
#   u'E-Play',
#   u'Pedicab (band)',
#   u'Jonathan Davis and the SFA',
#   u'Trabant (band)',
#   u'Datarock',
#   u'Babylon Zoo',
#   u'Le Tigre',
#   u'Radio 4 (band)',
#   u'Pain (musical project)'],
#  [u'Beverly Lee',
#   u'Katrina Parker',
#   u'Marilyn Wilson-Rutherford',
#   u'Katy Perry',
#   u'Gwen Stefani',
#   u'Paulina Gretzky',
#   u'Nicole Wray',
#   u'Moxie Raia',
#   u'Sue Lyon',
#   u'Sky Ferreira'],
#  [u'Sam Milby',
#   u'Alex Briley',
#   u'Jack Griffo',
#   u'Lil Yachty',
#   u'David Archuleta',
#   u'Jason Derulo',
#   u'Harry Wayne Casey',
#   u'Johnny Mathis',
#   u'Ronald Isley',
# ...

# %%
new_list_wiki = ['List of punk rock bands, 0\u2013K', 'List of punk rock bands, L\u2013Z', 'List of hard rock musicians (A\u2013M)', 'List of hard rock musicians (N\u2013Z)', 'List of R&B musicians', 'List of disco artists','List of disco artists (L\u2013R)','List of Euro disco artists','List of disco artists (F\u2013K)','List of disco artists (S\u2013Z)','List of disco artists (A\u2013E)']

# %%
for i in new_list_wiki:
    try:
        new_genre_artist = wikipedia.page(i)
        new_article = new_genre_artist.links
        content_list.append(new_article)
    except:
        print i 
        pass
# Out:
# List of punk rock bands, 0\u2013K
# List of punk rock bands, L\u2013Z
# List of hard rock musicians (A\u2013M)
# List of hard rock musicians (N\u2013Z)
# List of disco artists (L\u2013R)
# List of disco artists (F\u2013K)
# List of disco artists (S\u2013Z)
# List of disco artists (A\u2013E)

# %%
len(new_list_wiki)
# Out:
# 11

# %%
print new_list_wiki
# Out:
# ['List of punk rock bands, 0\\u2013K', 'List of punk rock bands, L\\u2013Z', 'List of hard rock musicians (A\\u2013M)', 'List of hard rock musicians (N\\u2013Z)', 'List of R&B musicians', 'List of disco artists', 'List of disco artists (L\\u2013R)', 'List of Euro disco artists', 'List of disco artists (F\\u2013K)', 'List of disco artists (S\\u2013Z)', 'List of disco artists (A\\u2013E)']

# %%
wikipedia.page("list of punk rock bands, L-Z")
# Out:
# <WikipediaPage 'List of punk rock bands, L–Z'>

# %%
wikipedia.page("list of disco artists (L-R)")
# Out:
# <WikipediaPage 'List of disco artists (L–R)'>

# %%
final_list_wiki = ["List of punk rock bands, 0-K", "List of punk rock bands, L-Z", "List of hard rock musicians (A-M)", "List of hard rock musicians (N-Z)","List of disco artists (L-R)", "List of disco artists (F-K)","List of disco artists (S-Z)","List of disco artists (A-E)"]

# %%
for i in final_list_wiki:
    try:
        final_genre_artist = wikipedia.page(i)
        final_article = final_genre_artist.links
        content_list.append(final_article)
    except:
        print i 
        pass

# %%
print content_list
# Out:
# [[u'Admiral Bailey', u'Admiral T', u'African Brothers', u'Aisha (reggae singer)', u'Al Anderson (The Wailers)', u'Al Campbell', u'Alaine', u'Alborosie', u'Alozade', u'Alpha & Omega (band)', u'Alpha Blondy', u'Althea & Donna', u'Alton Ellis', u'Andrew Tosh', u'Andru Branch', u'Annette Brissett', u'Ansell Collins', u'Anthony B', u'Anthony Johnson (musician)', u'Apache Indian (rapper)', u'Aston Barrett', u'Aswad (band)', u'Audio Active', u'Audrey Hall', u'Augustus "Gussie" Clarke', u'Augustus Pablo', u'Aura Lewis', u'B.B. Seaton', u'Baba Brooks', u'Baby Cham', u'Baby Wayne', u'Bad Brains', u'Barrington Levy', u'Barry Biggs', u'Barry Boom', u'Barry Brown (singer)', u'Bedouin Soundclash', u'Beenie Man', u'Benjamin Zephaniah', u'Beres Hammond', u'Beshara (band)', u'Big Joe (reggae)', u'Big Mountain (band)', u'Big Youth', u'Bim Sherman', u'Bitty McLean', u'Black Roots (band)', u'Black Slate', u'Black Uhuru', u'Blue Beat Records', u'Blue Riddim Band', u'Bob Andy', u'Bob Marley', u'Bob Marley
# ...

# %%
len(content_list)
# Out:
# 64

# %%
flattened = [val for sublist in content_list for val in sublist]

# %%
len(flattened)
# Out:
# 29450

# %%
flattened_new = [i.encode("ascii", "ignore") for i in flattened]

# %%
type(flattened_new[25])
# Out:
# str

# %%
type(flattened[2])
# Out:
# unicode

# %%
#test

import re

mystring = "Aisha (reggae singer)"
regex = re.sub("\s\([^)]*\)","", mystring)

# %%
regex
# Out:
# 'Aisha'

# %%
finallist=[re.sub("\s\([^)]*\)","", name) for name in flattened_new]

# %%
#list of final terms to input into itunes api > some of these include non-artists(includes publications)
#might be ok for now

finallist
# Out:
# ['Admiral Bailey',
#  'Admiral T',
#  'African Brothers',
#  'Aisha',
#  'Al Anderson',
#  'Al Campbell',
#  'Alaine',
#  'Alborosie',
#  'Alozade',
#  'Alpha & Omega',
#  'Alpha Blondy',
#  'Althea & Donna',
#  'Alton Ellis',
#  'Andrew Tosh',
#  'Andru Branch',
#  'Annette Brissett',
#  'Ansell Collins',
#  'Anthony B',
#  'Anthony Johnson',
#  'Apache Indian',
#  'Aston Barrett',
#  'Aswad',
#  'Audio Active',
#  'Audrey Hall',
#  'Augustus "Gussie" Clarke',
#  'Augustus Pablo',
#  'Aura Lewis',
#  'B.B. Seaton',
#  'Baba Brooks',
#  'Baby Cham',
#  'Baby Wayne',
#  'Bad Brains',
#  'Barrington Levy',
#  'Barry Biggs',
#  'Barry Boom',
#  'Barry Brown',
#  'Bedouin Soundclash',
#  'Beenie Man',
#  'Benjamin Zephaniah',
#  'Beres Hammond',
#  'Beshara',
#  'Big Joe',
#  'Big Mountain',
#  'Big Youth',
#  'Bim Sherman',
#  'Bitty McLean',
#  'Black Roots',
#  'Black Slate',
#  'Black Uhuru',
#  'Blue Beat Records',
#  'Blue Riddim Band',
#  'Bob Andy',
#  'Bob Marley',
# ...

# %%
len(finallist)
# Out:
# 29450

# %%
finallist[0][0]
# Out:
# 'A'

# %%
#split up terms that are only one name vs those that are multiple
finalfinalist = []

for term in finallist:
    if " " in term:
        finalfinalist.append(term.replace(" ", "+"))
    else:
        finalfinalist.append(term)

# %%
finalfinalist
# Out:
# ['Admiral+Bailey',
#  'Admiral+T',
#  'African+Brothers',
#  'Aisha',
#  'Al+Anderson',
#  'Al+Campbell',
#  'Alaine',
#  'Alborosie',
#  'Alozade',
#  'Alpha+&+Omega',
#  'Alpha+Blondy',
#  'Althea+&+Donna',
#  'Alton+Ellis',
#  'Andrew+Tosh',
#  'Andru+Branch',
#  'Annette+Brissett',
#  'Ansell+Collins',
#  'Anthony+B',
#  'Anthony+Johnson',
#  'Apache+Indian',
#  'Aston+Barrett',
#  'Aswad',
#  'Audio+Active',
#  'Audrey+Hall',
#  'Augustus+"Gussie"+Clarke',
#  'Augustus+Pablo',
#  'Aura+Lewis',
#  'B.B.+Seaton',
#  'Baba+Brooks',
#  'Baby+Cham',
#  'Baby+Wayne',
#  'Bad+Brains',
#  'Barrington+Levy',
#  'Barry+Biggs',
#  'Barry+Boom',
#  'Barry+Brown',
#  'Bedouin+Soundclash',
#  'Beenie+Man',
#  'Benjamin+Zephaniah',
#  'Beres+Hammond',
#  'Beshara',
#  'Big+Joe',
#  'Big+Mountain',
#  'Big+Youth',
#  'Bim+Sherman',
#  'Bitty+McLean',
#  'Black+Roots',
#  'Black+Slate',
#  'Black+Uhuru',
#  'Blue+Beat+Records',
#  'Blue+Riddim+Band',
#  'Bob+Andy',
#  'Bob+Marley',
# ...

# %%
# this is the url we have to use
#https://itunes.apple.com/search?term=jack+johnson&entity=album

url_template = "https://itunes.apple.com/search?term={}&entity=album"


url_list = []

for item in finalfinalist:
    newurl = url_template.replace("{}", item)
    url_list.append(newurl)

# %%
url_list
# Out:
# ['https://itunes.apple.com/search?term=Admiral+Bailey&entity=album',
#  'https://itunes.apple.com/search?term=Admiral+T&entity=album',
#  'https://itunes.apple.com/search?term=African+Brothers&entity=album',
#  'https://itunes.apple.com/search?term=Aisha&entity=album',
#  'https://itunes.apple.com/search?term=Al+Anderson&entity=album',
#  'https://itunes.apple.com/search?term=Al+Campbell&entity=album',
#  'https://itunes.apple.com/search?term=Alaine&entity=album',
#  'https://itunes.apple.com/search?term=Alborosie&entity=album',
#  'https://itunes.apple.com/search?term=Alozade&entity=album',
#  'https://itunes.apple.com/search?term=Alpha+&+Omega&entity=album',
#  'https://itunes.apple.com/search?term=Alpha+Blondy&entity=album',
#  'https://itunes.apple.com/search?term=Althea+&+Donna&entity=album',
#  'https://itunes.apple.com/search?term=Alton+Ellis&entity=album',
#  'https://itunes.apple.com/search?term=Andrew+Tosh&entity=album',
# ...

# %%
import pickle

with open('my_pickled_sample.pkl', 'w') as picklefile:
    pickle.dump(url_list, picklefile)

# %%
#created script to download each individual item as a txt file which is saved on my computer. following is script on
#the first 10

# %%
url_list[3191]
# Out:
# 'https://itunes.apple.com/search?term=Frankie+Laine&entity=album'

# %%
import json
import pandas as pd

#for i in range(1,11):
    #with open(str(i)+'.txt') as data_file:    
        #str = json.load(data_file)
        
with open("1.txt") as data_file:
    tester = json.load(data_file)

# %%
tester
# Out:
# {u'resultCount': 15,
#  u'results': [{u'amgArtistId': 29861,
#    u'artistId': 4038534,
#    u'artistName': u'Admiral Bailey',
#    u'artistViewUrl': u'https://itunes.apple.com/us/artist/admiral-bailey/id4038534?uo=4',
#    u'artworkUrl100': u'http://is5.mzstatic.com/image/thumb/Music/v4/03/5f/94/035f9477-5386-5470-5a40-82ade1d61959/source/100x100bb.jpg',
#    u'artworkUrl60': u'http://is5.mzstatic.com/image/thumb/Music/v4/03/5f/94/035f9477-5386-5470-5a40-82ade1d61959/source/60x60bb.jpg',
#    u'collectionCensoredName': u'The Best of Admiral Bailey',
#    u'collectionExplicitness': u'notExplicit',
#    u'collectionId': 318145456,
#    u'collectionName': u'The Best of Admiral Bailey',
#    u'collectionPrice': 11.99,
#    u'collectionType': u'Album',
#    u'collectionViewUrl': u'https://itunes.apple.com/us/album/the-best-of-admiral-bailey/id318145456?uo=4',
#    u'copyright': u'\u2117 1987 King Jammys',
#    u'country': u'USA',
#    u'currency': u'USD',
# ...

# %%
tester.pop("resultCount")
# Out:
# 15

# %%
print len(columntests)
print len(collectiontests)
# Out:
# 15
# 15

# %%
test_data = np.ones((len(collectiontests), len(columntests)))

# %%
appended_list = []

for i in tester["results"]:
    i = pd.Series(i)
    appended_list.append(i)
testtest = pd.concat(appended_list, axis = 1)

testtest = testtest.T

# %%
testtest
# Out:
#    amgArtistId   artistId                    artistName  \
# 0        29861    4038534                Admiral Bailey
# 1        29861    4038534                Admiral Bailey
# 2        29861    4038534                Admiral Bailey
# 3        29861    4038534                Admiral Bailey
# 4        29861    4038534                Admiral Bailey
# 5        29861    4038534                Admiral Bailey
# 6        29861    4038534                Admiral Bailey
# 7        29861    4038534                Admiral Bailey
# 8        29861    4038534                Admiral Bailey
# 9        29861    4038534                Admiral Bailey
# 10       21302    3217107  Josey Wales & Admiral Bailey
# 11       29861    4038534                Admiral Bailey
# 12       29861    4038534                Admiral Bailey
# 13         NaN  466044556                Admiral Halsey
# 14      850249  180225602                    Done Again
#
#                                         artistViewUrl  \
# ...

# %%
#adapt this for a few 

empty_list = []
for i in range(1,29451):
    try:
        with open(str(i)+'.txt') as data_file:    
            i = json.load(data_file)
            empty_list.append(i)
    except:
        print i
        pass
    
appended_list = []

for item in empty_list:
    for i in item["results"]:
        i = pd.Series(i)
        appended_list.append(i)
    testtest = pd.concat(appended_list, axis = 1)
    testtest = testtest.T
# Out:
# 1387
# 1392
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063
# 2064
# 2065
# 2066
# 2067
# 2068
# 2069
# 2070
# 2071
# 2072
# 2073
# 2074
# 2075
# 2076
# 2077
# 2078
# 2079
# 2080
# 2081
# 2082
# 2083
# 2084
# 2085
# 2086
# 2087
# 2088
# 2089
# 2090
# 2091
# 2092
# 2093
# 2094
# 2095
# 2096
# 2097
# 2098
# 2099
# 2100
# 2101
# 2102
# 2103
# 2104
# 2105
# 2106
# 2107
# 2108
# 2109
# 2110
# 2111
# 2112
# 2113
# 2114
# 2115
# 2116
# 2117
# 2118
# 2119
# 2120
# 2121
# 2122
# 2123
# 2124
# 2125
# 2126
# 2127
# 2128
# 2129
# 2130
# 2131
# 2132
# 2133
# 2134
# 2135
# 2136
# 2137
# 2138
# 2139
# 2140
# 2141
# 2142
# 2143
# 2144
# 2145
# 2146
# 2147
# 2148
# 2149
# 2150
# 2151
# 2152
# 2153
# 2154
# 2155
# 2156
# 2157
# 2158
# 2159
# 2160
# 2161
# 2162
# 2163
# 2164
# 2165
# 2166
# 2167
# 2168
# 2169
# 2170
# 2171
# 2172
# 2173
# 2174
# 2175
# 2176
# 2177
# 2178
# 2179
# 2180
# 2181
# 2182
# 2183
# 2184
# 2185
# 2186
# 2187
# 2188
# 2189
# 2190
# 2191
# 2192
# 2193
# 2194
# 2195
# 2196
# ...

# %%
testtest
# Out:
#       amgArtistId   artistId                    artistName  \
# 0           29861    4038534                Admiral Bailey
# 1           29861    4038534                Admiral Bailey
# 2           29861    4038534                Admiral Bailey
# 3           29861    4038534                Admiral Bailey
# 4           29861    4038534                Admiral Bailey
# 5           29861    4038534                Admiral Bailey
# 6           29861    4038534                Admiral Bailey
# 7           29861    4038534                Admiral Bailey
# 8           29861    4038534                Admiral Bailey
# 9           29861    4038534                Admiral Bailey
# 10          21302    3217107  Josey Wales & Admiral Bailey
# 11          29861    4038534                Admiral Bailey
# 12          29861    4038534                Admiral Bailey
# 13            NaN  466044556                Admiral Halsey
# 14         850249  180225602                    Done Again
# ...
