# %%
import pandas as pd
import numpy as np

sw = pd.read_csv('StarWars.csv')

sw.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %% [markdown]
# Let's use the Star Wars dataset again. Load it in and pull up the head.
#
# ```../../../1.2-study-design/assets/datasets/StarWars.csv```

# %% [markdown]
# #### Create a hypothesis involving different subsections of the data.
#
# For example:
# - Are respondents more likely to respond "Han" to the question "Who shot first?" if they also say they are fans of Star Trek?
#
# Type your hypothesis in a markdown cell below:

# %% [markdown]
# People who view Anakin Skywalker very favorably or favorably are more likely to say "No" to being fans of the Star Wars franchise

# %% [markdown]
# Use boolean indexing to create subsets of the data to support your hypothesis. See if you can answer questions using mutiple variables.

# %% [markdown]
# **Bonus** : Use matplotlib or seaborn to present your findings.

# %%
sw.columns
# Out:
# Index([u'RespondentID',
#        u'Have you seen any of the 6 films in the Star Wars franchise?',
#        u'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        u'Which of the following Star Wars films have you seen? Please select all that apply.',
#        u'Unnamed: 4', u'Unnamed: 5', u'Unnamed: 6', u'Unnamed: 7',
#        u'Unnamed: 8',
#        u'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        u'Unnamed: 10', u'Unnamed: 11', u'Unnamed: 12', u'Unnamed: 13',
#        u'Unnamed: 14',
#        u'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        u'Unnamed: 16', u'Unnamed: 17', u'Unnamed: 18', u'Unnamed: 19',
#        u'Unnamed: 20', u'Unnamed: 21', u'Unnamed: 22', u'Unnamed: 23',
#        u'Unnamed: 24', u'Unnamed: 25', u'Unnamed: 26', u'Unnamed: 27',
# ...

# %%
#list_of_columns = ["Do you consider yourself to be a fan of the Star Wars film franchise?","Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.", "Unnamed: 16", "Unnamed: 17", "Unnamed: 18", "Unnamed: 19", "Unnamed: 20", "Unnamed: 21", "Unnamed: 22", "Unnamed: 23", "Unnamed: 24", "Unnamed: 25", "Unnamed: 26", "Unnamed: 27", "Unnamed: 28"]

modified_sw = sw[list_of_columns]
modified_sw
# Out:
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                              Response
# 1                                                   Yes
# 2                                                   NaN
# 3                                                    No
# 4                                                   Yes
# 5                                                   Yes
# 6                                                   Yes
# 7                                                   Yes
# 8                                                   Yes
# 9                                                   Yes
# 10                                                   No
# 11                                                  NaN
# 12                                                  NaN
# 13                                                   No
# 14                                                  Yes
# ...

# %% [markdown]
# **Bonus 2** : Create another, more complex hypothesis, support it, and plot it below.

# %%
real_headers = [items for items in modified_sw.iloc[0]]
real_headers
# Out:
# ['Response',
#  'Han Solo',
#  'Luke Skywalker',
#  'Princess Leia Organa',
#  'Anakin Skywalker',
#  'Obi Wan Kenobi',
#  'Emperor Palpatine',
#  'Darth Vader',
#  'Lando Calrissian',
#  'Boba Fett',
#  'C-3P0',
#  'R2 D2',
#  'Jar Jar Binks',
#  'Padme Amidala',
#  'Yoda']

# %%
modified_sw.columns = real_headers

# %%
modified_sw.drop(modified_sw.index[0], inplace=True)
modified_sw
# Out:
# /Users/katty/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#      Response                                     Han Solo  \
# 1         Yes                               Very favorably
# 2         NaN                                          NaN
# 3          No                           Somewhat favorably
# 4         Yes                               Very favorably
# 5         Yes                               Very favorably
# 6         Yes                               Very favorably
# 7         Yes                               Very favorably
# 8         Yes                               Very favorably
# 9         Yes                               Very favorably
# 10         No  Neither favorably nor unfavorably (neutral)
# ...

# %%
modified_sw.head()
# Out:
#   Response            Han Solo      Luke Skywalker Princess Leia Organa  \
# 1      Yes      Very favorably      Very favorably       Very favorably
# 2      NaN                 NaN                 NaN                  NaN
# 3       No  Somewhat favorably  Somewhat favorably   Somewhat favorably
# 4      Yes      Very favorably      Very favorably       Very favorably
# 5      Yes      Very favorably  Somewhat favorably   Somewhat favorably
#
#        Anakin Skywalker      Obi Wan Kenobi   Emperor Palpatine  \
# 1        Very favorably      Very favorably      Very favorably
# 2                   NaN                 NaN                 NaN
# 3    Somewhat favorably  Somewhat favorably    Unfamiliar (N/A)
# 4        Very favorably      Very favorably  Somewhat favorably
# 5  Somewhat unfavorably      Very favorably    Very unfavorably
#
#           Darth Vader                             Lando Calrissian  \
# 1      Very favorably                             Unfamiliar (N/A)
# ...

# %%
no_only = modified_sw[modified_sw["Response"] == "No"]
no_only
# Out:
#      Response                                     Han Solo  \
# 3          No                           Somewhat favorably
# 10         No  Neither favorably nor unfavorably (neutral)
# 13         No                           Somewhat favorably
# 22         No  Neither favorably nor unfavorably (neutral)
# 31         No  Neither favorably nor unfavorably (neutral)
# 33         No                         Somewhat unfavorably
# 34         No                                          NaN
# 49         No                               Very favorably
# 60         No                           Somewhat favorably
# 65         No                           Somewhat favorably
# 68         No                               Very favorably
# 75         No                               Very favorably
# 77         No                           Somewhat favorably
# 82         No                           Somewhat favorably
# 89         No                               Very favorably
# ...

# %%
for item in range(1, 15):
    print no_only.iloc[:, item].value_counts()
# Out:
# Very favorably                                 140
# Somewhat favorably                              83
# Neither favorably nor unfavorably (neutral)     34
# Unfamiliar (N/A)                                13
# Somewhat unfavorably                             8
# Very unfavorably                                 1
# Name: Han Solo, dtype: int64
# Very favorably                                 145
# Somewhat favorably                              92
# Neither favorably nor unfavorably (neutral)     28
# Somewhat unfavorably                             7
# Unfamiliar (N/A)                                 6
# Very unfavorably                                 3
# Name: Luke Skywalker, dtype: int64
# Very favorably                                 137
# Somewhat favorably                              93
# Neither favorably nor unfavorably (neutral)     31
# Unfamiliar (N/A)                                 8
# Somewhat unfavorably                             6
# ...

# %%
no_only["Yoda"].value_counts()
# Out:
# Very favorably                                 150
# Somewhat favorably                              73
# Neither favorably nor unfavorably (neutral)     34
# Unfamiliar (N/A)                                 9
# Very unfavorably                                 6
# Somewhat unfavorably                             5
# Name: Yoda, dtype: int64
