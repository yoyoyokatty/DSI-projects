# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bb = pd.read_csv('assets/datasets/billboard.csv')

# %% [markdown]
# - dates as values
# - names of artists
# - genre cleaning
# - clean up time
# - change asterisks
# - num of weeks on chart
# - peak chart position

# %%
bb.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#   x2nd.week x3rd.week    ...     x67th.week x68th.week x69th.week x70th.week  \
# ...

# %%
bb["genre"].value_counts()
# Out:
# Rock           103
# Country         74
# Rap             58
# Rock'n'roll     34
# R&B             13
# R & B           10
# Pop              9
# Latin            9
# Electronica      4
# Gospel           1
# Jazz             1
# Reggae           1
# Name: genre, dtype: int64

# %%
def changeRandB(value):
    if value == "R & B":
        return "R&B"
    else:
        return value

def changerr(value):
    if value == "Rock'n'roll":
        return "Rock"
    else:
        return value

bb["genre"] = bb["genre"].apply(changerr)
bb["genre"] = bb["genre"].apply(changeRandB)

# %%
bb['genre'].value_counts()
# Out:
# Rock           137
# Country         74
# Rap             58
# R&B             23
# Pop              9
# Latin            9
# Electronica      4
# Gospel           1
# Jazz             1
# Reggae           1
# Name: genre, dtype: int64

# %%
bb["date.entered"] = pd.to_datetime(bb["date.entered"])

# %%
bb["date.peaked"] = pd.to_datetime(bb["date.peaked"])

# %%
bb
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
def AMremover(string):
    if " AM" in string:
        newstring = string.replace(" AM", "")
        if "," in newstring:
            newnewstring = newstring.replace(",", ":")
        return newnewstring

bb["time"] = bb["time"].apply(AMremover)

# %%
bb
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
bb["time"] = pd.to_timedelta(bb["time"])

# %%
bb
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...
