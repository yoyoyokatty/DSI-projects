# %%
#import pandas first
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
#this renders all your graphs inline. if you leave this out the graphs won't render properly and inline your note book

# %%
df = pd.read_csv('salary.csv')

# %%
df.head() #gives you the first 5
# Out:
#        sx    rk  yr         dg  yd     sl
# 0    male  full  25  doctorate  35  36350
# 1    male  full  13  doctorate  22  35350
# 2    male  full  10  doctorate  23  28200
# 3  female  full   7  doctorate  27  26775
# 4    male  full  19    masters  30  33696

# %%
df.tail() #gives you the last 5. it automatically will give you an index
# Out:
#         sx         rk  yr         dg  yd     sl
# 47  female  assistant   2  doctorate   2  15350
# 48    male  assistant   1  doctorate   1  16244
# 49  female  assistant   1  doctorate   1  16686
# 50  female  assistant   1  doctorate   1  15000
# 51  female  assistant   0  doctorate   2  20300

# %%
df.head(20) #lets you bring in more
# Out:
#         sx         rk  yr         dg  yd     sl
# 0     male       full  25  doctorate  35  36350
# 1     male       full  13  doctorate  22  35350
# 2     male       full  10  doctorate  23  28200
# 3   female       full   7  doctorate  27  26775
# 4     male       full  19    masters  30  33696
# 5     male       full  16  doctorate  21  28516
# 6   female       full   0    masters  32  24900
# 7     male       full  16  doctorate  18  31909
# 8     male       full  13    masters  30  31850
# 9     male       full  13    masters  31  32850
# 10    male       full  12  doctorate  22  27025
# 11    male  associate  15  doctorate  19  24750
# 12    male       full   9  doctorate  17  28200
# 13    male  associate   9    masters  27  23712
# 14    male       full   9  doctorate  24  25748
# 15    male       full   7  doctorate  15  29342
# 16    male       full  13  doctorate  20  31114
# 17    male  associate  11    masters  14  24742
# 18    male  associate  10    masters  15  22906
# ...

# %%
df.describe() #will pull all summary statistics
# Out:
#               yr         yd            sl
# count  52.000000  52.000000     52.000000
# mean    7.480769  16.115385  23797.653846
# std     5.507536  10.222340   5917.289154
# min     0.000000   1.000000  15000.000000
# 25%     3.000000   6.750000  18246.750000
# 50%     7.000000  15.500000  23719.000000
# 75%    11.000000  23.250000  27258.500000
# max    25.000000  35.000000  38045.000000

# %%
df.describe(percentiles=[.1, .2,.5]) #lets you adjsut your own percentiles
# Out:
#               yr         yd            sl
# count  52.000000  52.000000     52.000000
# mean    7.480769  16.115385  23797.653846
# std     5.507536  10.222340   5917.289154
# min     0.000000   1.000000  15000.000000
# 10%     1.000000   2.100000  16518.600000
# 20%     2.200000   4.200000  17680.000000
# 50%     7.000000  15.500000  23719.000000
# max    25.000000  35.000000  38045.000000

# %%
df.count() #count of each item in column
# Out:
# sx    52
# rk    52
# yr    52
# dg    52
# yd    52
# sl    52
# dtype: int64

# %%
df.mean() #provides the mean of each column that they can
# Out:
# yr        7.480769
# yd       16.115385
# sl    23797.653846
# dtype: float64

# %%
df.median()
# Out:
# yr        7.0
# yd       15.5
# sl    23719.0
# dtype: float64

# %%
df.max() #gives you more than just numeric data - will pull alphabetized data
# Out:
# sx       male
# rk       full
# yr         25
# dg    masters
# yd         35
# sl      38045
# dtype: object

# %%
df.min()
# Out:
# sx       female
# rk    assistant
# yr            0
# dg    doctorate
# yd            1
# sl        15000
# dtype: object

# %%
df.info() #gives you read out including object count and the data type, including null objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
# sx    52 non-null object
# rk    52 non-null object
# yr    52 non-null int64
# dg    52 non-null object
# yd    52 non-null int64
# sl    52 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 2.5+ KB

# %%
df.T
# Out:
#            0          1          2          3        4          5        6   \
# sx       male       male       male     female     male       male   female
# rk       full       full       full       full     full       full     full
# yr         25         13         10          7       19         16        0
# dg  doctorate  doctorate  doctorate  doctorate  masters  doctorate  masters
# yd         35         22         23         27       30         21       32
# sl      36350      35350      28200      26775    33696      28516    24900
#
#            7        8        9     ...             42         43         44  \
# sx       male     male     male    ...           male     female       male
# rk       full     full     full    ...      associate  assistant  assistant
# yr         16       13       13    ...              0          3          2
# dg  doctorate  masters  masters    ...      doctorate  doctorate  doctorate
# ...

# %%
df.sort_values(by="sx")
# Out:
#         sx         rk  yr         dg  yd     sl
# 51  female  assistant   0  doctorate   2  20300
# 50  female  assistant   1  doctorate   1  15000
# 23  female       full   8  doctorate  24  38045
# 30  female  assistant  10    masters  15  21600
# 33  female  associate   4    masters  33  20690
# 34  female  associate   6    masters  29  22450
# 36  female  assistant   8  doctorate  14  18304
# 43  female  assistant   3  doctorate   3  17250
# 27  female       full   5  doctorate  16  25500
# 46  female  assistant   2  doctorate   6  16150
# 49  female  assistant   1  doctorate   1  16686
# 3   female       full   7  doctorate  27  26775
# 6   female       full   0    masters  32  24900
# 47  female  assistant   2  doctorate   2  15350
# 29    male  associate   3    masters  17  23725
# 48    male  assistant   1  doctorate   1  16244
# 31    male  associate  11    masters  31  23300
# 32    male  assistant   9    masters  14  23713
# 45    male  assistant   2  doctorate   1  16094
# ...

# %%
df.sl
# Out:
# 0     36350
# 1     35350
# 2     28200
# 3     26775
# 4     33696
# 5     28516
# 6     24900
# 7     31909
# 8     31850
# 9     32850
# 10    27025
# 11    24750
# 12    28200
# 13    23712
# 14    25748
# 15    29342
# 16    31114
# 17    24742
# 18    22906
# 19    24450
# 20    19175
# 21    20525
# 22    27959
# 23    38045
# 24    24832
# 25    25400
# 26    24800
# 27    25500
# 28    26182
# 29    23725
# 30    21600
# 31    23300
# 32    23713
# 33    20690
# 34    22450
# 35    20850
# 36    18304
# 37    17095
# 38    16700
# 39    17600
# 40    18075
# 41    18000
# 42    20999
# 43    17250
# 44    16500
# 45    16094
# 46    16150
# 47    15350
# 48    16244
# 49    16686
# 50    15000
# 51    20300
# Name: sl, dtype: int64

# %%
df[0:5] #same syntax as slicing lists - you'll slice a row
# Out:
#        sx    rk  yr         dg  yd     sl
# 0    male  full  25  doctorate  35  36350
# 1    male  full  13  doctorate  22  35350
# 2    male  full  10  doctorate  23  28200
# 3  female  full   7  doctorate  27  26775
# 4    male  full  19    masters  30  33696

# %%
df['sl'] #this structure looks different - its no longer a dataframe (like df) but is a series. 
#each dataframe is made up of a series(e.g. column)
# Out:
# 0     36350
# 1     35350
# 2     28200
# 3     26775
# 4     33696
# 5     28516
# 6     24900
# 7     31909
# 8     31850
# 9     32850
# 10    27025
# 11    24750
# 12    28200
# 13    23712
# 14    25748
# 15    29342
# 16    31114
# 17    24742
# 18    22906
# 19    24450
# 20    19175
# 21    20525
# 22    27959
# 23    38045
# 24    24832
# 25    25400
# 26    24800
# 27    25500
# 28    26182
# 29    23725
# 30    21600
# 31    23300
# 32    23713
# 33    20690
# 34    22450
# 35    20850
# 36    18304
# 37    17095
# 38    16700
# 39    17600
# 40    18075
# 41    18000
# 42    20999
# 43    17250
# 44    16500
# 45    16094
# 46    16150
# 47    15350
# 48    16244
# 49    16686
# 50    15000
# 51    20300
# Name: sl, dtype: int64

# %%
list_of_cols_i_want = ['sx', 'yr']
df[list_of_cols_i_want] # df[['sx','yr']] is the same thing. also note that it comes out as a dataframe, not series
# Out:
#         sx  yr
# 0     male  25
# 1     male  13
# 2     male  10
# 3   female   7
# 4     male  19
# 5     male  16
# 6   female   0
# 7     male  16
# 8     male  13
# 9     male  13
# 10    male  12
# 11    male  15
# 12    male   9
# 13    male   9
# 14    male   9
# 15    male   7
# 16    male  13
# 17    male  11
# 18    male  10
# 19    male   6
# 20    male  16
# 21    male   8
# 22    male   7
# 23  female   8
# 24    male   9
# 25    male   5
# 26    male  11
# 27  female   5
# 28    male   3
# 29    male   3
# 30  female  10
# 31    male  11
# 32    male   9
# 33  female   4
# 34  female   6
# 35    male   1
# 36  female   8
# 37    male   4
# 38    male   4
# 39    male   4
# 40    male   3
# 41    male   3
# 42    male   0
# 43  female   3
# 44    male   2
# 45    male   2
# 46  female   2
# 47  female   2
# 48    male   1
# 49  female   1
# 50  female   1
# 51  female   0

# %%
#picking rows and columns together
df.iloc[0:10, 2:4] #rows, columns
# Out:
#    yr         dg
# 0  25  doctorate
# 1  13  doctorate
# 2  10  doctorate
# 3   7  doctorate
# 4  19    masters
# 5  16  doctorate
# 6   0    masters
# 7  16  doctorate
# 8  13    masters
# 9  13    masters

# %%
#picking specific cell
df.iloc[1,3] #row1, column3
# Out:
# 'doctorate'

# %%
df['yr'].hist() #can customize through matplotlib
df['yr'].hist(figsize = (10,4), color ="black")

# %%
fig =  df['yr'].hist(figsize = (10,4), color ="darkorange")

plt.style.use("fivethirtyeight")
fig.set_title("Chart of stuff", y = 1.01)

ax = plt.gca()

ax.set_ylabel("Frequency", fontsize =14)
ax.set_xlabel("years", fontsize =14)

plt.show()

# %%
sw = pd.read_csv('StarWars.csv', encoding = "latin-1")

# %%
sw.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %%
sw.tail()
# Out:
#       RespondentID  \
# 1182  3.288389e+09
# 1183  3.288379e+09
# 1184  3.288375e+09
# 1185  3.288373e+09
# 1186  3.288373e+09
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1182                                                Yes
# 1183                                                Yes
# 1184                                                 No
# 1185                                                Yes
# 1186                                                Yes
#
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1182                                                Yes
# 1183                                                Yes
# 1184                                                NaN
# 1185                                                Yes
# 1186                                                 No
#
#      Which of the following Star Wars films have you seen? Please select all that apply.  \
# ...

# %%
sw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 38 columns):
# RespondentID                                                                                                                                     1186 non-null float64
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                     1187 non-null object
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                            837 non-null object
# Which of the following Star Wars films have you seen? Please select all that apply.                                                              674 non-null object
# Unnamed: 4                                                                                                                                       572 non-null object
# ...

# %%
sw.iloc[1,2]
# Out:
# 'Yes'

# %%
sw["Which character shot first?"]
# Out:
# 0                               Response
# 1       I don't understand this question
# 2                                    NaN
# 3       I don't understand this question
# 4       I don't understand this question
# 5                                 Greedo
# 6                                    Han
# 7                                    Han
# 8                                    Han
# 9                                    Han
# 10      I don't understand this question
# 11                                   NaN
# 12                                   NaN
# 13                                Greedo
# 14      I don't understand this question
# 15                                   Han
# 16                                   Han
# 17                                   Han
# 18                                Greedo
# 19                                   Han
# 20                                Greedo
# 21                                   Han
# 22      I don't understand this question
# ...

# %%
sw.iloc[2, 2:8]
# Out:
# Do you consider yourself to be a fan of the Star Wars film franchise?                  NaN
# Which of the following Star Wars films have you seen? Please select all that apply.    NaN
# Unnamed: 4                                                                             NaN
# Unnamed: 5                                                                             NaN
# Unnamed: 6                                                                             NaN
# Unnamed: 7                                                                             NaN
# Name: 2, dtype: object

# %%
sw["RespondentID"]
# Out:
# 0                NaN
# 1       3.292880e+09
# 2       3.292880e+09
# 3       3.292765e+09
# 4       3.292763e+09
# 5       3.292731e+09
# 6       3.292719e+09
# 7       3.292685e+09
# 8       3.292664e+09
# 9       3.292654e+09
# 10      3.292640e+09
# 11      3.292638e+09
# 12      3.292635e+09
# 13      3.292609e+09
# 14      3.292597e+09
# 15      3.292587e+09
# 16      3.292583e+09
# 17      3.292581e+09
# 18      3.292573e+09
# 19      3.292565e+09
# 20      3.292562e+09
# 21      3.292522e+09
# 22      3.292521e+09
# 23      3.292512e+09
# 24      3.292483e+09
# 25      3.292465e+09
# 26      3.292448e+09
# 27      3.292420e+09
# 28      3.292384e+09
# 29      3.292380e+09
#             ...
# 1157    3.288426e+09
# 1158    3.288423e+09
# 1159    3.288423e+09
# 1160    3.288422e+09
# 1161    3.288421e+09
# 1162    3.288418e+09
# 1163    3.288418e+09
# 1164    3.288417e+09
# 1165    3.288415e+09
# 1166    3.288414e+09
# 1167    3.288413e+09
# 1168    3.288410e+09
# ...

# %%
df.loc[:, "RespondentID"] = df["RespondentID"].astype('str') #saving all respondents for RespondentID and saving it as a string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 38 columns):
# RespondentID                                                                                                                                     1187 non-null object
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                     1187 non-null object
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                            837 non-null object
# Which of the following Star Wars films have you seen? Please select all that apply.                                                              674 non-null object
# Unnamed: 4                                                                                                                                       572 non-null object
# ...

# %%
df.loc[:5, "RespondentID"] #getting first 5 rows
# Out:
# 0             nan
# 1    3292879998.0
# 2    3292879538.0
# 3    3292765271.0
# 4    3292763116.0
# 5    3292731220.0
# Name: RespondentID, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1187, step=1)

# %%
#we want any column that has "you" in it

#df.columns will score all the columns

cols = [x for x in df.columns if 'Do' in x] #it is case sensitive!
cols
# Out:
# ['Do you consider yourself to be a fan of the Star Wars film franchise?',
#  'Do you consider yourself to be a fan of the Expanded Universe?\xef\xbf\xbd\xef\xbf\xbd',
#  'Do you consider yourself to be a fan of the Star Trek franchise?']

# %%
df.loc[:50, cols]
# Out:
#    Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                            Response
# 1                                                 Yes
# 2                                                 NaN
# 3                                                  No
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                 No
# 11                                                NaN
# 12                                                NaN
# 13                                                 No
# 14                                                Yes
# 15                                                Yes
# ...

# %%
df["YesNo"] = 1 #this lets you add a column called "YesNo"

# %%
df.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           nan                                           Response
# 1  3292879998.0                                                Yes
# 2  3292879538.0                                                 No
# 3  3292765271.0                                                Yes
# 4  3292763116.0                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...
